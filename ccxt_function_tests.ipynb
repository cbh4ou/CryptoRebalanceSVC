# %%
import configparser
from crypto_balancer.ccxt_exchange import CCXTExchange, exchanges

config = configparser.ConfigParser()
config.read('config.ini')
exchange = 'binanceus'
config = config[exchange]
exchange = CCXTExchange("binanceus",
                        config['api_key'],
                        config['api_secret'],
                        do_cancel_orders=False)

# %%
start = "REP"
end = "USDT"
#exchange.get_smart_route(start, end)
#exchange.exch.market('REP/USD')
exchange.get_portfolio_total('BTC')
# Out:
# [{'direction': 'sell', 'symbol': 'ETH/BTC'}]
# None
# None
# [{'direction': 'buy', 'symbol': 'BTC/USDT'}]
# [{'direction': 'sell', 'symbol': 'BCH/BTC'}]
# [{'direction': 'sell', 'symbol': 'LTC/BTC'}]
# [{'direction': 'sell', 'symbol': 'ADA/BTC'}]
# [{'symbol': 'XLM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BAT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ETC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ZRX/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'BNB/BTC'}]
# [{'direction': 'sell', 'symbol': 'LINK/BTC'}]
# None
# [{'symbol': 'RVN/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'DASH/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'ZEC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ALGO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'IOTA/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'direction': 'buy', 'symbol': 'BTC/BUSD'}]
# [{'direction': 'sell', 'symbol': 'DOGE/BTC'}]
# [{'symbol': 'WAVES/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'ATOM/BTC'}]
# [{'symbol': 'NEO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'VET/BTC'}]
# [{'symbol': 'QTUM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'EOS/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ICX/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'ENJ/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ONT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ZIL/BUSD', 'direction': 'sell'}, {'symbol': 'BTC/BUSD', 'direction': 'buy'}]
# [{'direction': 'buy', 'symbol': 'BTC/USDC'}]
# [{'direction': 'sell', 'symbol': 'XTZ/BTC'}]
# [{'symbol': 'HBAR/BUSD', 'direction': 'sell'}, {'symbol': 'BTC/BUSD', 'direction': 'buy'}]
# [{'symbol': 'OMG/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'MATIC/BTC'}]
# [{'symbol': 'ONE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'VTHO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'KNC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'COMP/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'REN/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'MANA/BTC'}]
# [{'symbol': 'HNT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'MKR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'buy', 'symbol': 'BTC/DAI'}]
# [{'symbol': 'BAND/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'STMX/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'STORJ/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'SOL/BTC'}]
# [{'direction': 'sell', 'symbol': 'UNI/BTC'}]
# [{'symbol': 'EGLD/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'PAXG/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'OXT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ZEN/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'FIL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'AAVE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'GRT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SUSHI/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'ANKR/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'SHIB/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'CRV/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'AVAX/BTC'}]
# [{'symbol': 'AXS/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'DOT/BTC'}]
# [{'symbol': 'CTSI/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'YFI/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': '1INCH/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'FTM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'NEAR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'LRC/BTC'}]
# [{'symbol': 'KSHIB/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'LPT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SLP/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'NMR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ANT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'AUDIO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'GALA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'CHZ/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ENS/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'OGN/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'XNO/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'TLM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SNX/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'APE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'REQ/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'WBTC/BTC'}]
# [{'symbol': 'VOXEL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'direction': 'sell', 'symbol': 'TRX/BTC'}]
# [{'symbol': 'FLOW/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'FLUX/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BICO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SPELL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'COTI/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'API3/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'CELR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'IMX/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'JASMY/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'ALICE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'DAR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'RNDR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'T/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'RLC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'THETA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BNT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'TFUEL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'GTC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LOKA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# [{'symbol': 'ALPINE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SANTOS/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'PORTO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LAZIO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SKL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'OCEAN/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'KSM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'VITE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ROSE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BOND/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'WAXP/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ICP/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'FET/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LTO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'RAD/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'RARE/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'CELO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ACH/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'OP/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'CLV/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'FORTH/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'KDA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SYS/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ILV/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'REEF/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LDO/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'TUSD/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LSK/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'POND/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'DGB/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BAL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'GLM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'GAL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'ASTR/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BTRST/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'QNT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'SAND/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'KAVA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'POLYX/USD', 'direction': 'sell'}, {'symbol': 'BTC/USD', 'direction': 'buy'}]
# [{'symbol': 'AXL/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'STG/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'APT/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'MASK/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'LOOM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'BOSON/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'MXC/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'PROM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'DIA/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# [{'symbol': 'JAM/USDT', 'direction': 'sell'}, {'symbol': 'BTC/USDT', 'direction': 'buy'}]
# None
# 3722169.817165072

# %%
""" symbol = 'BTC/USD'
type = 'limit'
side = 'buy'
quote = 92.05
price = 1
amount = 10

#exchange.exch.exch.exch.calculate_fee(symbol=symbol, type=type, side=side,
#                      amount=amount, price=price)
#exchange.exch.exch.exch.fetch_open_orders(symbol="BTC/USDT")
#exchange.exch.get_limit("ADA/USDT") """

current = {'USD' : 80, 'USDT' : 20}
targets = {'BTC' : 23, 'USDT' : 5, 'ADA' : 10, 'GALA' : 5}

# %%
codes = [code for code, amount in balance['total'].items()]
exchange.get_matched_pairs(["BTC", "USDT"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 codes = [code for code, amount in balance['total'].items()]
#       2 exchange.get_matched_pairs(["BTC", "USDT"])
#
# NameError: name 'balance' is not defined
