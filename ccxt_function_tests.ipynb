# %%
import configparser
from crypto_balancer.ccxt_exchange import CCXTExchange, exchanges

config = configparser.ConfigParser()
config.read('config.ini')
exchange = 'binanceus'
config = config[exchange]
exchange = CCXTExchange("binanceus",
                        ["BTC", "ETH"],
                        config['api_key'],
                        config['api_secret'],
                        do_cancel_orders=False)

# %%
exchange.free_balances
# Out:
# {'BTC': '0.00004165',
#  'ETH': '0.00000934',
#  'USDT': '168.35721956',
#  'BCH': '0.00000808',
#  'LTC': '0.00000734',
#  'ADA': '0.07400000',
#  'BAT': '0.00913000',
#  'ETC': '0.00171000',
#  'ZRX': '0.00757000',
#  'LINK': '0.00940600',
#  'REP': '0.02300000',
#  'RVN': '0.05080000',
#  'ZEC': '0.00000750',
#  'ALGO': '43.40694000',
#  'IOTA': '0.00027000',
#  'BUSD': '0.00813007',
#  'DOGE': '4.76900000',
#  'WAVES': '0.85357000',
#  'ATOM': '0.00034550',
#  'VET': '0.20900000',
#  'QTUM': '0.00050100',
#  'EOS': '0.00468000',
#  'ICX': '0.41627000',
#  'ENJ': '0.09960000',
#  'XTZ': '0.00735000',
#  'HBAR': '31.67840000',
#  'OMG': '0.13000000',
#  'MATIC': '0.03070000',
#  'ONE': '0.06840000',
#  'VTHO': '0.46300000',
#  'KNC': '0.00000300',
#  'COMP': '0.00000129',
#  'REN': '0.23150000',
#  'MANA': '2.69348000',
#  'HNT': '0.00832000',
#  'MKR': '0.00083260',
#  'BAND': '3.40124000',
#  'STORJ': '0.00641000',
#  'SOL': '0.00720000',
#  'UNI': '0.00688000',
#  'EGLD': '0.00001500',
#  'PAXG': '0.00000050',
#  'OXT': '0.00100000',
#  'ZEN': '0.00070700',
#  'FIL': '0.00006500',
#  'AAVE': '0.00005260',
#  'GRT': '0.00756000',
#  'SUSHI': '2.48837100',
#  'AMP': '0.04220000',
#  'ANKR': '0.04030000',
#  'CRV': '0.05640000',
#  'AVAX': '0.00259000',
#  'AXS': '0.00196000',
#  'CTSI': '0.44600000',
#  'YFI': '0.00000020',
#  '1INCH': '0.03300000',
#  'BOBA': '0.13000000',
#  'FTM': '6.56900000',
#  'NEAR': '0.02690000',
#  'LRC': '7.77400000',
#  'LPT': '0.00270000',
#  'NMR': '0.00131500',
#  'ANT': '1.20180000',
#  'AUDIO': '0.06960000',
#  'GALA': '172.82800000',
#  'CHZ': '57.27750000',
#  'ENS': '0.00005000',
#  'OGN': '0.55000000',
#  'XNO': '0.00343000',
#  'SNX': '0.08435000',
#  'APE': '0.00564000',
#  'REQ': '0.60000000',
#  'FLOW': '0.00508000',
#  'FLUX': '0.00705000',
#  'BICO': '0.00862000',
#  'SPELL': '0.25700000',
#  'API3': '0.15605000',
#  'IMX': '0.00706000',
#  'JASMY': '49.50140000',
#  'RNDR': '0.96480500',
#  'RLC': '0.03455000',
#  'THETA': '0.09045000',
#  'BNT': '0.07968000',
#  'TFUEL': '0.19800000',
#  'GTC': '3.55180000',
#  'PORTO': '0.21202000',
#  'LAZIO': '0.09746000',
#  'SKL': '0.39250000',
#  'OCEAN': '30.34600000',
#  'VITE': '43.44005000',
#  'ROSE': '0.07130000',
#  'BOND': '0.00091000',
#  'WAXP': '0.54900000',
#  'ICP': '0.00760000',
#  'FET': '0.37600000',
#  'LTO': '5.15200000',
#  'OP': '2.70764500',
#  'KDA': '0.00195000',
#  'SYS': '0.53200000',
#  'REEF': '2306.80800000',
#  'LDO': '0.00680000',
#  'GAL': '0.00024800',
#  'POLYX': '0.00960000',
#  'USD': '1513.27689433'}
